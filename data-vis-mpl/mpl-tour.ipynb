# %% [markdown]
# ## A tour of matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
plt.style.use('bmh')

# %% [markdown]
# ### Simple line plot

# %%
## initialize the axes
fig = plt.figure(figsize=(8,4))
ax = fig.add_subplot(111)

## format axes
ax.set_ylabel('volts')
ax.set_title('a sine wave')

t = np.arange(0.0, 1.0, 0.01)
s = np.sin(2*np.pi*t)
line = ax.plot(t, s, color='blue', lw=2)
ax.legend([line[0]],["something"])

# %% [markdown]
# ### More complicated with plot

# %%
import numpy as np
import matplotlib.pyplot as plt

## initialize the figure
fig = plt.figure(figsize=(8,8))

## the data
t = np.arange(0.0, 1.0, 0.01)
s = np.sin(2*np.pi*t)

## the top axes
ax1 = fig.add_subplot(3,1,1)
ax1.set_ylabel('volts')
ax1.set_title('a sine wave')

line1 = ax1.plot(t, s+5.0, color='blue', lw=2)
line2 = ax1.plot(t, s+2.5, color='red', lw=2)
line3 = ax1.plot(t, s, color='orange', lw=2)

## the middle axes
ax2 = fig.add_subplot(3,1,2)
ax2.set_ylabel('volts')
ax2.set_title('a sine wave')

line1 = ax2.plot(t, s+5.0, color='black', lw=2,linestyle="--")
line2 = ax2.plot(t, s+2.5, color='black', lw=2,linestyle="-.")
line3 = ax2.plot(t, s, color='#000000', lw=2,linestyle=":")

## the thrid axes
ax3 = fig.add_subplot(3,1,3)
ax3.set_ylabel('volts')
ax3.set_title('a sine wave')

line1 = ax3.plot(t,s+5.0, color='blue', marker="+")
line2 = ax3.plot(t,s+2.5, color='red', marker="o")
line3 = ax3.plot(t,s, color='orange', marker="^")

## adjust the space between plots
plt.subplots_adjust(wspace=0.2,hspace=.4)

# %% [markdown]
# ### Box plots

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(111)

x1 = np.random.normal(0,1,50)
x2 = np.random.normal(1,1,50)
x3 = np.random.normal(2,1,50)

p = ax.boxplot([x1,x2,x3])

# %% [markdown]
# ### Histogram

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

x = np.random.normal(0,1,1000)
numBins = 50
out = ax.hist(x,numBins,color='green',alpha=0.8)

# %% [markdown]
# ### Bar plots

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)

## the data
N = 5
menMeans = [18, 35, 30, 35, 27]
menStd =   [2, 3, 4, 1, 2]
womenMeans = [25, 32, 34, 20, 25]
womenStd =   [3, 5, 2, 3, 3]

## necessary variables
ind = np.arange(N)                # the x locations for the groups
width = 0.35                      # the width of the bars

## the bars
rects1 = ax.bar(ind, menMeans, width,
                color='black',
                yerr=menStd,
                error_kw=dict(elinewidth=2,ecolor='red'))

rects2 = ax.bar(ind+width*2, womenMeans, width,
                    color='red',
                    yerr=womenStd,
                    error_kw=dict(elinewidth=2,ecolor='black'))

# axes and labels
ax.set_xlim(-width,len(ind)+width)
ax.set_ylim(0,45)
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
xTickMarks = ['Group'+str(i) for i in range(1,6)]
ax.set_xticks(ind)
xtickNames = ax.set_xticklabels(xTickMarks)
plt.setp(xtickNames, rotation=45, fontsize=10)

## add a legend
p = ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )

# %% [markdown]
# ### Another bar plot

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111,projection='3d')
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array. To demonstrate this,
    # the first bar of each set will be colored cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)

p = ax.set_xlabel('X')
p = ax.set_ylabel('Y')
p = ax.set_zlabel('Z')

# %% [markdown]
# ### Scatter plot

# %%
fig = plt.figure(figsize=(10,8))
ax1 = fig.add_subplot(121)

## the data
N=1000
x = np.random.randn(N)
y = np.random.randn(N)

## left panel
ax1.scatter(x,y,color='blue',s=5,edgecolor='none')
ax1.set_aspect(1./ax1.get_data_ratio()) # make axes square


## right panel
ax2 = fig.add_subplot(122)
props = dict(alpha=0.1, edgecolors='none' )

handles = []
colors = ['blue', 'green', 'magenta', 'cyan']
for color in colors:
    x = np.random.randn(N)
    y = np.random.randn(N)
    s = np.random.randint(50,200)
    handles.append(ax2.scatter(x, y, c=color, s=10, **props))

ax2.set_ylim([-5,11])
ax2.set_xlim([-5,11])

ax2.legend(handles, colors)
ax2.grid(True)
ax2.set_aspect(1./ax2.get_data_ratio())

# %% [markdown]
# ## Customizing

# %% [markdown]
# ### Styles
#
# There are many styles out there dark

# %%
fig = plt.figure(figsize=(8,6))
print(plt.style.available)
plt.style.use('classic')

with plt.style.context('fivethrityeight'):
    L = 6
    x = np.linspace(0, L)
    ncolors = len(plt.rcParams['axes.prop_cycle'])
    shift = np.linspace(0, L, ncolors, endpoint=False)
    for s in shift:
        plt.plot(x, np.sin(x + s), 'o-')
    plt.xlabel('x-axis')
    plt.ylabel('y-axis')
    plt.title('title')
# Out:
# ['dark_background', 'seaborn-talk', 'classic', 'bmh', 'ggplot', 'seaborn', 'fivethirtyeight', 'seaborn-notebook', 'seaborn-whitegrid', 'seaborn-dark', 'seaborn-muted', 'seaborn-white', 'seaborn-darkgrid', 'seaborn-colorblind', 'seaborn-deep', 'seaborn-ticks', 'seaborn-pastel', 'seaborn-paper', 'fast', 'seaborn-bright', 'seaborn-poster', '_classic_test', 'seaborn-dark-palette', 'tableau-colorblind10', 'Solarize_Light2', 'grayscale']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/style/core.py in use(style)
#     110             try:
# --> 111                 rc = rc_params_from_file(style, use_default_template=False)
#     112                 _apply_style(rc)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in rc_params_from_file(fname, fail_on_error, use_default_template)
#    1133     """
# -> 1134     config_from_file = _rc_params_in_file(fname, fail_on_error)
#    1135
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in _rc_params_in_file(fname, fail_on_error)
#    1049     rc_temp = {}
# -> 1050     with _open_file_or_url(fname) as fd:
#    1051         try:
#
# ~/anaconda3/lib/python3.6/contextlib.py in __enter__(self)
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in _open_file_or_url(fname)
#    1034             encoding = "utf-8"
# -> 1035         with io.open(fname, encoding=encoding) as f:
#    1036             yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fivethrityeight'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-b5137eb0c6ae> in <module>()
#       3 plt.style.use('classic')
#       4
# ----> 5 with plt.style.context('fivethrityeight'):
#       6     L = 6
#       7     x = np.linspace(0, L)
#
# ~/anaconda3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/style/core.py in context(style, after_reset)
#     146         mpl.rcdefaults()
#     147     try:
# --> 148         use(style)
#     149     except:
#     150         # Restore original settings before raising errors during the update.
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/style/core.py in use(style)
#     115                     "{!r} not found in the style library and input is not a "
#     116                     "valid URL or path; see `style.available` for list of "
# --> 117                     "available styles".format(style))
#     118
#     119
#
# OSError: 'fivethrityeight' not found in the style library and input is not a valid URL or path; see `style.available` for list of available styles

# %% [markdown]
# ### xkcd

# %%
plt.xkcd()

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.xticks([])
plt.yticks([])
ax.set_ylim([-30, 10])

data = np.ones(100)
data[70:] -= np.arange(30)

plt.annotate(
    'THE DAY I REALIZED\nI COULD COOK BACON\nWHENEVER I WANTED',
    xy=(70, 1), arrowprops=dict(arrowstyle='->'), xytext=(15, -10))

plt.plot(data)

plt.xlabel('time')
plt.ylabel('my overall health')

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.bar([-0.125, 1.0-0.125], [0, 100], 0.25)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.set_xticks([0, 1])
ax.set_xlim([-0.5, 1.5])
ax.set_ylim([0, 110])
ax.set_xticklabels(['CONFIRMED BY\nEXPERIMENT', 'REFUTED BY\nEXPERIMENT'])
plt.yticks([])

plt.title("CLAIMS OF SUPERNATURAL POWERS")
# Out:
# Text(0.5,1,'CLAIMS OF SUPERNATURAL POWERS')

# %% [markdown]
# ### Pandas

# %%
import pandas as pd
import numpy as np

x_data = np.arange(0, 4, .01)
y_data = np.sin(x_data)
df = pd.DataFrame({'x':x_data, 'sinx':np.sin(x_data), 'cosx':np.cos(x_data)})
df = df.set_index('x')
df.head()
# Out:
#          cosx      sinx
# x
# 0.00  1.00000  0.000000
# 0.01  0.99995  0.010000
# 0.02  0.99980  0.019999
# 0.03  0.99955  0.029996
# 0.04  0.99920  0.039989

# %%
fig = plt.figure(figsize=(8,6))
ax = df.cosx.plot()
print(ax)
ax.set_title("foo")
# Out:
# AxesSubplot(0.125,0.1;0.775x0.8)
# Text(0.5,1,'foo')

# %%
ax = df.cosx.plot()
ax = df.sinx.plot()
ax.clear()
ax = df.cosx.plot()
ax.set_title('sin(x) & cos(x)')
ax.set_ylabel('volts')
ax

# %%
## we can also be more explicit by providing the ax
fig, ax_list = plt.subplots(2,1)
cols = ['sinx', 'cosx']
for ax, col in zip(ax_list, cols):
    df[col].plot(ax=ax)
    ax.legend()
top_ax = ax_list[0]
top_ax.set_ylim(bottom=-1, top=1)
# Out:
# (-1, 1)

# %% [markdown]
# ### Seaborn

# %%
plt.style.use('classic')
import seaborn as sns
seaborn_grid = sns.lmplot(x="x", y="sinx", data=df.reset_index())
#Combined with matplotlib
seaborn_grid.axes[0,0].hlines(0, -1, 5)
ax = seaborn_grid.axes

# %%
import matplotlib.pyplot as plt
sns.set(style="ticks")

# Create a dataset with many short random walks
rs = np.random.RandomState(4)
pos = rs.randint(-1, 2, (20, 5)).cumsum(axis=1)
pos -= pos[:, 0, np.newaxis]
step = np.tile(range(5), 20)
walk = np.repeat(range(20), 5)
df = pd.DataFrame(np.c_[pos.flat, step, walk],
                  columns=["position", "step", "walk"])

# Initialize a grid of plots with an Axes for each walk
grid = sns.FacetGrid(df, col="walk", hue="walk", col_wrap=5, size=1.5)

# Draw a horizontal line to show the starting point
grid.map(plt.axhline, y=0, ls=":", c=".5")

# Draw a line plot to show the trajectory of each random walk
grid.map(plt.plot, "step", "position", marker="o", ms=4)

# Adjust the tick positions and labels
grid.set(xticks=np.arange(5), yticks=[-3, 3],
         xlim=(-.5, 4.5), ylim=(-3.5, 3.5))

# Adjust the arrangement of the plots
grid.fig.tight_layout(w_pad=1)
